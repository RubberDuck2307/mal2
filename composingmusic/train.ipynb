# %%
import os
import numpy as np
import pretty_midi
from sklearn.model_selection import train_test_split
import tensorflow as tf

MIDI_DIR = "data/archive/"


def midi_to_notes(midi_path):
    midi = pretty_midi.PrettyMIDI(midi_path)

    notes = []
    for instrument in midi.instruments:
        for note in instrument.notes:
            notes.append([
                note.pitch
            ])
    if len(notes) == 0:
        return None
    return np.array(notes)

all_notes = []
for file in os.listdir(MIDI_DIR):
    if file.endswith(".mid") or file.endswith(".midi"):
        note_data = midi_to_notes(os.path.join(MIDI_DIR, file))
        if note_data is not None:
            all_notes.append(note_data)

all_notes = np.concatenate(all_notes, axis=0)
print("Shape of all notes:", all_notes.shape)

note_tensor = tf.convert_to_tensor(all_notes, dtype=tf.int32)
SEQ_LEN = 10

def make_sequences(note_tensor, seq_len=SEQ_LEN):
    X, y = [], []
    notes = note_tensor.numpy()
    for i in range(len(notes) - seq_len):
        X.append(notes[i:i+seq_len])
        y.append(notes[i+seq_len])
    return tf.convert_to_tensor(X, dtype=tf.int32), tf.convert_to_tensor(y, dtype=tf.int32)

X_train, y_train = make_sequences(note_tensor)
X_test, y_test = make_sequences(note_tensor)

X_train = tf.squeeze(X_train, axis=-1)
X_test = tf.squeeze(X_test, axis=-1)
# Out:
# 2025-11-02 10:32:54.047862: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/user/pythonenv/default/lib/python3.12/site-packages/pretty_midi/pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Shape of all notes: (4060, 1)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762075977.530908  209174 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13321 MB memory:  -> device: 0, name: AMD Radeon RX 9070 XT, pci bus id: 0000:03:00.0

# %%
from tensorflow.keras import layers, models

vocab_size = 128
embed_dim = 64
lstm_units = 128
num_classes = 128


model = models.Sequential([
    layers.Input(shape=(None,)),
    layers.Embedding(input_dim=vocab_size, output_dim=embed_dim),
    layers.LSTM(lstm_units, return_sequences=True),
    layers.LSTM(lstm_units),
    layers.Dense(num_classes, activation='softmax')
])


model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, None, 64)       │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, None, 128)      │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 255,104 (996.50 KB)
#  Trainable params: 255,104 (996.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping



early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=1000,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1,
)
val_loss, val_acc = model.evaluate(X_test, y_test)
print(f"\n✅ Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_acc:.4f}")
# Out:
# Epoch 1/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.0291 - loss: 4.1613 - val_accuracy: 0.0363 - val_loss: 3.8687
# Epoch 2/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0346 - loss: 3.8786 - val_accuracy: 0.0378 - val_loss: 3.8630
# Epoch 3/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0336 - loss: 3.8680 - val_accuracy: 0.0338 - val_loss: 3.8524
# Epoch 4/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0328 - loss: 3.8678 - val_accuracy: 0.0358 - val_loss: 3.8522
# Epoch 5/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0319 - loss: 3.8640 - val_accuracy: 0.0358 - val_loss: 3.8515
# Epoch 6/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.0343 - loss: 3.8583 - val_accuracy: 0.0343 - val_loss: 3.8428
# Epoch 7/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0353 - loss: 3.8586 - val_accuracy: 0.0319 - val_loss: 3.8461
# Epoch 8/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0336 - loss: 3.8534 - val_accuracy: 0.0353 - val_loss: 3.8476
# Epoch 9/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0326 - loss: 3.8620 - val_accuracy: 0.0410 - val_loss: 3.8402
# Epoch 10/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0356 - loss: 3.8513 - val_accuracy: 0.0378 - val_loss: 3.8296
# Epoch 11/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0402 - loss: 3.8393 - val_accuracy: 0.0417 - val_loss: 3.8195
# Epoch 12/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0442 - loss: 3.8187 - val_accuracy: 0.0491 - val_loss: 3.7990
# Epoch 13/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0464 - loss: 3.7998 - val_accuracy: 0.0541 - val_loss: 3.7808
# Epoch 14/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0506 - loss: 3.7841 - val_accuracy: 0.0479 - val_loss: 3.7972
# Epoch 15/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0489 - loss: 3.7845 - val_accuracy: 0.0467 - val_loss: 3.7598
# Epoch 16/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0489 - loss: 3.7592 - val_accuracy: 0.0523 - val_loss: 3.7286
# Epoch 17/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0499 - loss: 3.7456 - val_accuracy: 0.0501 - val_loss: 3.7307
# Epoch 18/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0580 - loss: 3.7278 - val_accuracy: 0.0662 - val_loss: 3.6986
# Epoch 19/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0551 - loss: 3.7198 - val_accuracy: 0.0642 - val_loss: 3.6821
# Epoch 20/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0605 - loss: 3.7122 - val_accuracy: 0.0627 - val_loss: 3.6885
# Epoch 21/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0546 - loss: 3.7186 - val_accuracy: 0.0595 - val_loss: 3.6892
# Epoch 22/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0556 - loss: 3.7170 - val_accuracy: 0.0607 - val_loss: 3.6825
# Epoch 23/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0625 - loss: 3.6852 - val_accuracy: 0.0642 - val_loss: 3.6742
# Epoch 24/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0649 - loss: 3.6852 - val_accuracy: 0.0714 - val_loss: 3.6527
# Epoch 25/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0630 - loss: 3.6683 - val_accuracy: 0.0768 - val_loss: 3.6380
# Epoch 26/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0627 - loss: 3.6673 - val_accuracy: 0.0686 - val_loss: 3.6308
# Epoch 27/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0721 - loss: 3.6438 - val_accuracy: 0.0773 - val_loss: 3.6129
# Epoch 28/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0714 - loss: 3.6324 - val_accuracy: 0.0714 - val_loss: 3.6413
# Epoch 29/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0694 - loss: 3.6319 - val_accuracy: 0.0785 - val_loss: 3.6103
# Epoch 30/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0756 - loss: 3.6096 - val_accuracy: 0.0867 - val_loss: 3.5621
# Epoch 31/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0775 - loss: 3.6007 - val_accuracy: 0.0899 - val_loss: 3.5679
# Epoch 32/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0775 - loss: 3.5872 - val_accuracy: 0.0919 - val_loss: 3.5429
# Epoch 33/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0874 - loss: 3.5529 - val_accuracy: 0.1020 - val_loss: 3.4950
# Epoch 34/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0983 - loss: 3.5134 - val_accuracy: 0.1077 - val_loss: 3.4798
# Epoch 35/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0988 - loss: 3.5159 - val_accuracy: 0.1106 - val_loss: 3.4657
# Epoch 36/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.1030 - loss: 3.4966 - val_accuracy: 0.1072 - val_loss: 3.4569
# Epoch 37/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1017 - loss: 3.4718 - val_accuracy: 0.1244 - val_loss: 3.4155
# Epoch 38/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1116 - loss: 3.4531 - val_accuracy: 0.1212 - val_loss: 3.3923
# Epoch 39/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1178 - loss: 3.4276 - val_accuracy: 0.1269 - val_loss: 3.4003
# Epoch 40/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1101 - loss: 3.4461 - val_accuracy: 0.1222 - val_loss: 3.3935
# Epoch 41/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1136 - loss: 3.4204 - val_accuracy: 0.1269 - val_loss: 3.3768
# Epoch 42/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1111 - loss: 3.4148 - val_accuracy: 0.1281 - val_loss: 3.3374
# Epoch 43/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1370 - loss: 3.3649 - val_accuracy: 0.1370 - val_loss: 3.3100
# Epoch 44/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1338 - loss: 3.3412 - val_accuracy: 0.1543 - val_loss: 3.2717
# Epoch 45/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1398 - loss: 3.3106 - val_accuracy: 0.1514 - val_loss: 3.2528
# Epoch 46/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1472 - loss: 3.2778 - val_accuracy: 0.1585 - val_loss: 3.2246
# Epoch 47/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1605 - loss: 3.2566 - val_accuracy: 0.1706 - val_loss: 3.1844
# Epoch 48/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1583 - loss: 3.2391 - val_accuracy: 0.1830 - val_loss: 3.1663
# Epoch 49/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1728 - loss: 3.1868 - val_accuracy: 0.1837 - val_loss: 3.1135
# Epoch 50/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1674 - loss: 3.1581 - val_accuracy: 0.1886 - val_loss: 3.0962
# Epoch 51/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1800 - loss: 3.1270 - val_accuracy: 0.1827 - val_loss: 3.1431
# Epoch 52/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1798 - loss: 3.1257 - val_accuracy: 0.2072 - val_loss: 3.0175
# Epoch 53/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1914 - loss: 3.0722 - val_accuracy: 0.2156 - val_loss: 3.0089
# Epoch 54/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1906 - loss: 3.0820 - val_accuracy: 0.2202 - val_loss: 2.9930
# Epoch 55/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2054 - loss: 3.0342 - val_accuracy: 0.2163 - val_loss: 2.9623
# Epoch 56/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2136 - loss: 2.9991 - val_accuracy: 0.2412 - val_loss: 2.9114
# Epoch 57/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2215 - loss: 2.9653 - val_accuracy: 0.2449 - val_loss: 2.8979
# Epoch 58/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2242 - loss: 2.9471 - val_accuracy: 0.2479 - val_loss: 2.8600
# Epoch 59/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2353 - loss: 2.9189 - val_accuracy: 0.2565 - val_loss: 2.8278
# Epoch 60/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2331 - loss: 2.8865 - val_accuracy: 0.2583 - val_loss: 2.8098
# Epoch 61/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2531 - loss: 2.8483 - val_accuracy: 0.2768 - val_loss: 2.7341
# Epoch 62/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2580 - loss: 2.8163 - val_accuracy: 0.2901 - val_loss: 2.6987
# Epoch 63/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2533 - loss: 2.8014 - val_accuracy: 0.2679 - val_loss: 2.7458
# Epoch 64/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2632 - loss: 2.7811 - val_accuracy: 0.2970 - val_loss: 2.6643
# Epoch 65/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2632 - loss: 2.7608 - val_accuracy: 0.2956 - val_loss: 2.6783
# Epoch 66/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.2728 - loss: 2.7288 - val_accuracy: 0.2980 - val_loss: 2.6340
# Epoch 67/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2879 - loss: 2.7063 - val_accuracy: 0.2995 - val_loss: 2.6400
# Epoch 68/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2872 - loss: 2.6800 - val_accuracy: 0.3309 - val_loss: 2.5481
# Epoch 69/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3015 - loss: 2.6278 - val_accuracy: 0.3207 - val_loss: 2.5269
# Epoch 70/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2983 - loss: 2.6038 - val_accuracy: 0.3432 - val_loss: 2.4823
# Epoch 71/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3044 - loss: 2.5808 - val_accuracy: 0.3444 - val_loss: 2.4652
# Epoch 72/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3173 - loss: 2.5539 - val_accuracy: 0.3395 - val_loss: 2.4605
# Epoch 73/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3212 - loss: 2.5175 - val_accuracy: 0.3654 - val_loss: 2.3938
# Epoch 74/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3395 - loss: 2.4602 - val_accuracy: 0.3746 - val_loss: 2.3405
# Epoch 75/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3425 - loss: 2.4356 - val_accuracy: 0.3602 - val_loss: 2.3643
# Epoch 76/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3427 - loss: 2.4408 - val_accuracy: 0.3807 - val_loss: 2.2965
# Epoch 77/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3514 - loss: 2.4021 - val_accuracy: 0.3874 - val_loss: 2.2869
# Epoch 78/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3630 - loss: 2.3672 - val_accuracy: 0.4025 - val_loss: 2.2349
# Epoch 79/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3637 - loss: 2.3318 - val_accuracy: 0.4111 - val_loss: 2.1998
# Epoch 80/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3943 - loss: 2.2648 - val_accuracy: 0.4291 - val_loss: 2.1455
# Epoch 81/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3963 - loss: 2.2420 - val_accuracy: 0.4294 - val_loss: 2.1493
# Epoch 82/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4091 - loss: 2.1986 - val_accuracy: 0.4509 - val_loss: 2.0708
# Epoch 83/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4136 - loss: 2.1893 - val_accuracy: 0.4467 - val_loss: 2.0620
# Epoch 84/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4346 - loss: 2.1349 - val_accuracy: 0.4654 - val_loss: 2.0131
# Epoch 85/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4358 - loss: 2.1020 - val_accuracy: 0.4709 - val_loss: 1.9709
# Epoch 86/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4523 - loss: 2.0367 - val_accuracy: 0.5059 - val_loss: 1.8874
# Epoch 87/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4521 - loss: 2.0085 - val_accuracy: 0.5156 - val_loss: 1.8553
# Epoch 88/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4484 - loss: 2.0104 - val_accuracy: 0.5012 - val_loss: 1.8831
# Epoch 89/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4649 - loss: 1.9693 - val_accuracy: 0.5128 - val_loss: 1.8443
# Epoch 90/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4867 - loss: 1.9010 - val_accuracy: 0.5321 - val_loss: 1.7476
# Epoch 91/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4990 - loss: 1.8823 - val_accuracy: 0.5156 - val_loss: 1.7856
# Epoch 92/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4857 - loss: 1.8868 - val_accuracy: 0.5437 - val_loss: 1.7155
# Epoch 93/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4862 - loss: 1.8757 - val_accuracy: 0.5412 - val_loss: 1.7171
# Epoch 94/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5030 - loss: 1.8223 - val_accuracy: 0.5748 - val_loss: 1.6669
# Epoch 95/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5195 - loss: 1.7781 - val_accuracy: 0.5494 - val_loss: 1.6852
# Epoch 96/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5247 - loss: 1.7547 - val_accuracy: 0.5810 - val_loss: 1.5925
# Epoch 97/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5284 - loss: 1.7167 - val_accuracy: 0.5679 - val_loss: 1.5951
# Epoch 98/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5338 - loss: 1.6881 - val_accuracy: 0.5857 - val_loss: 1.5598
# Epoch 99/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5410 - loss: 1.6622 - val_accuracy: 0.5909 - val_loss: 1.5343
# Epoch 100/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5452 - loss: 1.6556 - val_accuracy: 0.5891 - val_loss: 1.5426
# Epoch 101/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5519 - loss: 1.6352 - val_accuracy: 0.5941 - val_loss: 1.5220
# Epoch 102/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5437 - loss: 1.6456 - val_accuracy: 0.6175 - val_loss: 1.4480
# Epoch 103/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5677 - loss: 1.5986 - val_accuracy: 0.6183 - val_loss: 1.4465
# Epoch 104/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5684 - loss: 1.5868 - val_accuracy: 0.5960 - val_loss: 1.4802
# Epoch 105/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5827 - loss: 1.5416 - val_accuracy: 0.6170 - val_loss: 1.4345
# Epoch 106/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5817 - loss: 1.5266 - val_accuracy: 0.6390 - val_loss: 1.3798
# Epoch 107/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5975 - loss: 1.4810 - val_accuracy: 0.6469 - val_loss: 1.3523
# Epoch 108/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6012 - loss: 1.4816 - val_accuracy: 0.6422 - val_loss: 1.3530
# Epoch 109/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5995 - loss: 1.4810 - val_accuracy: 0.6640 - val_loss: 1.3033
# Epoch 110/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6138 - loss: 1.4349 - val_accuracy: 0.6659 - val_loss: 1.3045
# Epoch 111/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6010 - loss: 1.4555 - val_accuracy: 0.6509 - val_loss: 1.3316
# Epoch 112/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6160 - loss: 1.4164 - val_accuracy: 0.6901 - val_loss: 1.2311
# Epoch 113/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6435 - loss: 1.3317 - val_accuracy: 0.6916 - val_loss: 1.1888
# Epoch 114/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6131 - loss: 1.3861 - val_accuracy: 0.6674 - val_loss: 1.2564
# Epoch 115/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6321 - loss: 1.3506 - val_accuracy: 0.7025 - val_loss: 1.1576
# Epoch 116/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6516 - loss: 1.2752 - val_accuracy: 0.7044 - val_loss: 1.1509
# Epoch 117/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6672 - loss: 1.2365 - val_accuracy: 0.7111 - val_loss: 1.1202
# Epoch 118/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6593 - loss: 1.2490 - val_accuracy: 0.7007 - val_loss: 1.1316
# Epoch 119/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6575 - loss: 1.2555 - val_accuracy: 0.7027 - val_loss: 1.1316
# Epoch 120/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6316 - loss: 1.2978 - val_accuracy: 0.7119 - val_loss: 1.1012
# Epoch 121/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6738 - loss: 1.1856 - val_accuracy: 0.7220 - val_loss: 1.0473
# Epoch 122/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7007 - loss: 1.1166 - val_accuracy: 0.7427 - val_loss: 0.9906
# Epoch 123/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7005 - loss: 1.1109 - val_accuracy: 0.7491 - val_loss: 0.9908
# Epoch 124/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6975 - loss: 1.1220 - val_accuracy: 0.7538 - val_loss: 0.9746
# Epoch 125/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7005 - loss: 1.1102 - val_accuracy: 0.7427 - val_loss: 1.0050
# Epoch 126/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6901 - loss: 1.1329 - val_accuracy: 0.7398 - val_loss: 0.9959
# Epoch 127/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6988 - loss: 1.1036 - val_accuracy: 0.7580 - val_loss: 0.9545
# Epoch 128/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7106 - loss: 1.0561 - val_accuracy: 0.7694 - val_loss: 0.9093
# Epoch 129/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7040 - loss: 1.0771 - val_accuracy: 0.7484 - val_loss: 0.9765
# Epoch 130/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6696 - loss: 1.1569 - val_accuracy: 0.7570 - val_loss: 0.9594
# Epoch 131/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6941 - loss: 1.0946 - val_accuracy: 0.7558 - val_loss: 0.9372
# Epoch 132/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6948 - loss: 1.0906 - val_accuracy: 0.7738 - val_loss: 0.8923
# Epoch 133/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7365 - loss: 0.9678 - val_accuracy: 0.8057 - val_loss: 0.8021
# Epoch 134/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7504 - loss: 0.9319 - val_accuracy: 0.8104 - val_loss: 0.7941
# Epoch 135/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7526 - loss: 0.9099 - val_accuracy: 0.8106 - val_loss: 0.7839
# Epoch 136/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7635 - loss: 0.8763 - val_accuracy: 0.8225 - val_loss: 0.7469
# Epoch 137/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7985 - loss: 0.7943 - val_accuracy: 0.8558 - val_loss: 0.6584
# Epoch 138/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8069 - loss: 0.7630 - val_accuracy: 0.8486 - val_loss: 0.6663
# Epoch 139/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8057 - loss: 0.7696 - val_accuracy: 0.8568 - val_loss: 0.6352
# Epoch 140/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8111 - loss: 0.7300 - val_accuracy: 0.8528 - val_loss: 0.6485
# Epoch 141/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8146 - loss: 0.7235 - val_accuracy: 0.8751 - val_loss: 0.5797
# Epoch 142/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8267 - loss: 0.6887 - val_accuracy: 0.8728 - val_loss: 0.5904
# Epoch 143/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8064 - loss: 0.7398 - val_accuracy: 0.8440 - val_loss: 0.6409
# Epoch 144/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8084 - loss: 0.7455 - val_accuracy: 0.8694 - val_loss: 0.5972
# Epoch 145/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8193 - loss: 0.7066 - val_accuracy: 0.8620 - val_loss: 0.6083
# Epoch 146/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8101 - loss: 0.7038 - val_accuracy: 0.8731 - val_loss: 0.5753
# Epoch 147/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8242 - loss: 0.6810 - val_accuracy: 0.8770 - val_loss: 0.5611
# Epoch 148/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8291 - loss: 0.6643 - val_accuracy: 0.8753 - val_loss: 0.5523
# Epoch 149/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8210 - loss: 0.6801 - val_accuracy: 0.8464 - val_loss: 0.6192
# Epoch 150/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8010 - loss: 0.7276 - val_accuracy: 0.8610 - val_loss: 0.5974
# Epoch 151/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8089 - loss: 0.7039 - val_accuracy: 0.8714 - val_loss: 0.5710
# Epoch 152/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7998 - loss: 0.7179 - val_accuracy: 0.8716 - val_loss: 0.5461
# Epoch 153/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8232 - loss: 0.6777 - val_accuracy: 0.8672 - val_loss: 0.5697
# Epoch 154/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8183 - loss: 0.6750 - val_accuracy: 0.8689 - val_loss: 0.5521
# Epoch 155/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8435 - loss: 0.6166 - val_accuracy: 0.8960 - val_loss: 0.4887
# Epoch 156/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8437 - loss: 0.6007 - val_accuracy: 0.8842 - val_loss: 0.5170
# Epoch 157/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8462 - loss: 0.5955 - val_accuracy: 0.9047 - val_loss: 0.4621
# Epoch 158/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8657 - loss: 0.5340 - val_accuracy: 0.8968 - val_loss: 0.4648
# Epoch 159/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8738 - loss: 0.5173 - val_accuracy: 0.9289 - val_loss: 0.3921
# Epoch 160/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8706 - loss: 0.5211 - val_accuracy: 0.9156 - val_loss: 0.4230
# Epoch 161/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8647 - loss: 0.5485 - val_accuracy: 0.9044 - val_loss: 0.4413
# Epoch 162/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8506 - loss: 0.5606 - val_accuracy: 0.9138 - val_loss: 0.4213
# Epoch 163/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8768 - loss: 0.5011 - val_accuracy: 0.9146 - val_loss: 0.4001
# Epoch 164/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8807 - loss: 0.4666 - val_accuracy: 0.9279 - val_loss: 0.3758
# Epoch 165/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8933 - loss: 0.4459 - val_accuracy: 0.9356 - val_loss: 0.3536
# Epoch 166/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9049 - loss: 0.4233 - val_accuracy: 0.9402 - val_loss: 0.3385
# Epoch 167/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8896 - loss: 0.4589 - val_accuracy: 0.9230 - val_loss: 0.3760
# Epoch 168/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8953 - loss: 0.4374 - val_accuracy: 0.9311 - val_loss: 0.3405
# Epoch 169/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9032 - loss: 0.4101 - val_accuracy: 0.9407 - val_loss: 0.3256
# Epoch 170/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9089 - loss: 0.3948 - val_accuracy: 0.9417 - val_loss: 0.3152
# Epoch 171/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9104 - loss: 0.3958 - val_accuracy: 0.9289 - val_loss: 0.3433
# Epoch 172/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9040 - loss: 0.4135 - val_accuracy: 0.9373 - val_loss: 0.3278
# Epoch 173/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9086 - loss: 0.4088 - val_accuracy: 0.9467 - val_loss: 0.3057
# Epoch 174/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9190 - loss: 0.3652 - val_accuracy: 0.9494 - val_loss: 0.2905
# Epoch 175/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9215 - loss: 0.3444 - val_accuracy: 0.9506 - val_loss: 0.2738
# Epoch 176/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9220 - loss: 0.3438 - val_accuracy: 0.9402 - val_loss: 0.2996
# Epoch 177/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9160 - loss: 0.3563 - val_accuracy: 0.9454 - val_loss: 0.2892
# Epoch 178/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9185 - loss: 0.3570 - val_accuracy: 0.9523 - val_loss: 0.2687
# Epoch 179/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9237 - loss: 0.3345 - val_accuracy: 0.9393 - val_loss: 0.2955
# Epoch 180/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9057 - loss: 0.3839 - val_accuracy: 0.9328 - val_loss: 0.3122
# Epoch 181/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8953 - loss: 0.3936 - val_accuracy: 0.9356 - val_loss: 0.3089
# Epoch 182/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8874 - loss: 0.4402 - val_accuracy: 0.9240 - val_loss: 0.3314
# Epoch 183/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8778 - loss: 0.4359 - val_accuracy: 0.9333 - val_loss: 0.3265
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9523 - loss: 0.2687
#
# ✅ Validation Loss: 0.2687 | Validation Accuracy: 0.9523

# %%
def sample_from_probs(preds, temperature):

    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-8) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    return np.random.choice(len(preds), p=preds)

def generate_music(model, seed_sequence, num_steps=20, temperature=4.0):

    generated = []
    current_seq = seed_sequence

    for _ in range(num_steps):
        input_seq = tf.expand_dims(current_seq, axis=0)
        preds = model.predict(input_seq, verbose=0)[0]

        next_pitch = sample_from_probs(preds, temperature)
        generated.append(next_pitch)

        current_seq = np.append(current_seq[1:], next_pitch)

    return np.array(generated)

seed_seq = X_train[0]
generated_notes = generate_music(model, seed_seq, num_steps=20)
print("Generated notes shape:", generated_notes.shape)


def pitches_to_midi(pitch_array, output_file, start_time=0.0, step=0.5, velocity=100):

    midi = pretty_midi.PrettyMIDI()
    piano = pretty_midi.Instrument(program=4)

    time = start_time
    for pitch in pitch_array:
        pitch = int(np.clip(pitch, 0, 127))
        piano.notes.append(pretty_midi.Note(
            velocity=velocity,
            pitch=pitch,
            start=time,
            end=time + step
        ))
        time += step

    midi.instruments.append(piano)
    midi.write(output_file)
    print(f"MIDI saved to {output_file}")


pitches_to_midi(generated_notes, "generated_music3.mid")
# Out:
# Generated notes shape: (20,)
# MIDI saved to generated_music3.mid
